# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# mount drive
from google.colab import drive
drive.mount('/content/drive')

# pwd gives you the current working directory (good to know but not necessary)
# %pwd

# cd lets you change the current working directory, in our case we move to the data directory (necessary)
# %cd /content/drive/MyDrive/'Colab Notebooks'/ClimateData_Project2/data/

# ls lists the contents of your current working directory (good to know but not necessary)
# %ls

# load the kaggle data as an example
tmp_df = pd.read_csv(filepath_or_buffer ="kaggle/FAOSTAT_data_1-10-2022.csv")

# %%
df  = pd.read_csv('C:/Users/krish/Downloads/Temperature_data/Temp_data.csv')

# %%
df_2 = pd.read_csv('C:/Users/krish/Downloads/Temperature_data/co2_data.csv')
df_2.head(10)
#df_2.info()
df_3 = df_2[['country','year','share_of_temperature_change_from_ghg','temperature_change_from_ch4','temperature_change_from_co2','temperature_change_from_ghg','temperature_change_from_n2o']]
df_3.info()
#sns.barplot(x = 'country', y = 'temperature_change_from_co2', data = df_3)
#plt.show()

print(df_3.duplicated().sum())
df_3.fillna(df_3.mean())#df_3 = df_3.dropna(axis = 0, how = 'all')
#df_3
sns.lineplot(x = 'year',y = 'temperature_change_from_ch4',data = df_3,label = 'temp change from ch4')
sns.lineplot(x = 'year',y = 'temperature_change_from_co2',data = df_3,label = 'temp change from co2' )#sns.lineplot(x = 'year',y = 'temperature_change_from_ghg',data = df_3,label = 'temp change from ghg' )
sns.lineplot(x = 'year',y = 'temperature_change_from_n2o',data = df_3,label = 'temp change from n2o' )
plt.legend()
plt.xlabel('year')
plt.ylabel('Temp change from ch4 and co2 and n20')
plt.title('Temperature change due to release of various gases')
#df_3.head(5)
#df_3 = df_3.dropna(axis = 1, how = 'all')
#df_3.head(100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48058 entries, 0 to 48057
# Data columns (total 7 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   country                               48058 non-null  object
#  1   year                                  48058 non-null  int64
#  2   share_of_temperature_change_from_ghg  41724 non-null  float64
#  3   temperature_change_from_ch4           37620 non-null  float64
#  4   temperature_change_from_co2           41724 non-null  float64
#  5   temperature_change_from_ghg           41724 non-null  float64
#  6   temperature_change_from_n2o           37620 non-null  float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.6+ MB
# 0
# ...

# %%
df = df[['Area','Element Code','Element','Months','Year','Value']]
#df_1 = df.replace(['Value'],['delta_temp'])
#df_1
new_name = {'Value'   : 'delta_in_temp'}
df_1 = df.rename(new_name, axis = 1)
df_1
# Out:
#                Area  Element Code             Element               Months  \
# 0       Afghanistan          7271  Temperature change              January
# 1       Afghanistan          7271  Temperature change              January
# 2       Afghanistan          7271  Temperature change              January
# 3       Afghanistan          7271  Temperature change              January
# 4       Afghanistan          7271  Temperature change              January
# ...             ...           ...                 ...                  ...
# 229920     Zimbabwe          7271  Temperature change  Meteorological year
# 229921     Zimbabwe          7271  Temperature change  Meteorological year
# 229922     Zimbabwe          7271  Temperature change  Meteorological year
# 229923     Zimbabwe          7271  Temperature change  Meteorological year
# 229924     Zimbabwe          7271  Temperature change  Meteorological year
#
#         Year  delta_in_temp
# 0       1961          0.746
# ...

# %%
sns.lineplot(x = 'Year',y = 'delta_in_temp',label = 'increasing trend',data = df_1)
plt.xlabel('year')
plt.ylabel('change in temperature')
plt.title('Temperature change over years')
plt.legend()

# %%
df_4 = df_1[df_1['Area'].isin(
    ['India', 'Antarctica', 'France', 'Netherlands',
     'United Kingdom', 'Africa', 'United States','China','Germany'])]

# %%
df_4
df_4.value_counts()
df_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6120 entries, 7140 to 144210
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area          6120 non-null   object
#  1   Element Code  6120 non-null   int64
#  2   Element       6120 non-null   object
#  3   Months        6120 non-null   object
#  4   Year          6120 non-null   int64
#  5   Value         6120 non-null   float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 334.7+ KB

# %%
dictionary = {'Value': 'int'}
df_4 = df_4.astype(dictionary)
sns.lmplot(x ='Year',y ='Value',data  = df_4)

# %%
sns.boxplot(x ='Area',y ='Value',data  = df_4)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Value'>
